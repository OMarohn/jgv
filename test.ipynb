# %%
import xml.etree.ElementTree as ET

# Laden Sie die XML-Datei
tree = ET.parse('./public/sitemap.xml')

namespaces = {'ns': 'http://www.sitemaps.org/schemas/sitemap/0.9'}

# Finden Sie alle 'url' Elemente
urls = tree.findall('ns:url', namespaces)

# Für jedes 'url' Element, extrahieren Sie das 'loc' Element und drucken Sie den Text
for url in urls:
    loc = url.find('ns:loc', namespaces)
    if loc is not None:
        print(loc.text)
# Out:
# [<Element '{http://www.sitemaps.org/schemas/sitemap/0.9}url' at 0x000001B07EDC93F0>, <Element '{http://www.sitemaps.org/schemas/sitemap/0.9}url' at 0x000001B07EDC9670>, <Element '{http://www.sitemaps.org/schemas/sitemap/0.9}url' at 0x000001B07EDC9120>, <Element '{http://www.sitemaps.org/schemas/sitemap/0.9}url' at 0x000001B07EDC9490>, <Element '{http://www.sitemaps.org/schemas/sitemap/0.9}url' at 0x000001B07EDC8950>, <Element '{http://www.sitemaps.org/schemas/sitemap/0.9}url' at 0x000001B07EDC8AE0>, <Element '{http://www.sitemaps.org/schemas/sitemap/0.9}url' at 0x000001B07EDC8F40>, <Element '{http://www.sitemaps.org/schemas/sitemap/0.9}url' at 0x000001B07EDC8270>, <Element '{http://www.sitemaps.org/schemas/sitemap/0.9}url' at 0x000001B07EDC82C0>, <Element '{http://www.sitemaps.org/schemas/sitemap/0.9}url' at 0x000001B07EDC8FE0>, <Element '{http://www.sitemaps.org/schemas/sitemap/0.9}url' at 0x000001B07EDC9C60>, <Element '{http://www.sitemaps.org/schemas/sitemap/0.9}url' at 0x000001B0
# ...
